# %% [markdown]
# # Google Playstore EDA

# %%
# import libraries
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../dataset/googleplaystore.csv')

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df['Size'].value_counts()
# Out:
# Size
# Varies with device    1695
# 11M                    198
# 12M                    196
# 14M                    194
# 13M                    191
#                       ...
# 253k                     1
# 992k                     1
# 658k                     1
# 73k                      1
# 246k                     1
# Name: count, Length: 461, dtype: int64

# %%
df['Size'].nunique()
# Out:
# 461

# %% [markdown]
# ### 1. Import Libraries

# %%
# import Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### 2. Load DataSet And Cleaning

# %%
df = pd.read_csv('../dataset/googleplaystore.csv')
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# - Important Things

# %%
# SET option for Max rows and columns
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)

# %%
# Hide All Warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Exploration

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df.shape
# Out:
# (10841, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  int64
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10841 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10839 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.1+ MB

# %%
# HOW MUCH NUMERIC WHICH SHOW

df.describe()

# show only 2, but actually more columns are numeric we can seee in head()
# Out:
#             Rating       Reviews
# count  9367.000000  1.084100e+04
# mean      4.191513  4.441119e+05
# std       0.515735  2.927629e+06
# min       1.000000  0.000000e+00
# 25%       4.000000  3.800000e+01
# 50%       4.300000  2.094000e+03
# 75%       4.500000  5.476800e+04
# max       5.000000  7.815831e+07

# %% [markdown]
# ### Issue in 3 Columns
# 1. Size
# 2. Price
# 3. Installs

# %% [markdown]
# ## Size Column

# %%
df['Size'].value_counts()
# Out:
# Size
# Varies with device    1695
# 11M                    198
# 12M                    196
# 14M                    194
# 13M                    191
# 15M                    184
# 17M                    160
# 19M                    154
# 26M                    149
# 16M                    149
# 25M                    143
# 20M                    139
# 21M                    138
# 10M                    136
# 24M                    136
# 18M                    133
# 23M                    117
# 22M                    114
# 29M                    103
# 27M                     97
# 28M                     95
# 30M                     84
# 33M                     79
# 3.3M                    77
# 37M                     76
# 35M                     72
# 31M                     70
# 2.9M                    69
# 2.3M                    68
# 2.5M                    68
# 3.4M                    65
# 2.8M                    65
# 32M                     63
# 3.7M                    63
# ...

# %%
df['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %% [markdown]
# ---
# ## Observations
# ### 3 type of Values
# - 'Varies with device'
# - Where 'M' present
# - Where 'K' present
# ---

# %%
# Check Numm Value
df['Size'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# - No missing value, So we are good to go

# %% [markdown]
# Verify the Number of 3 different Values

# %%
df['Size'].loc[df['Size'].str.contains('M')].value_counts().sum()
# Out:
# np.int64(8830)

# %%
df['Size'].loc[df['Size'].str.contains('k')].value_counts().sum()
# Out:
# np.int64(316)

# %%
df['Size'].loc[df['Size'] == 'Varies with device'].value_counts().sum()
# Out:
# np.int64(1695)

# %%
1695+316+8830
# Out:
# 10841

# %%
len(df)
# Out:
# 10841

# %% [markdown]
# #### Convert Whole Size Into Bytes

# %%
# lets define a function

def covert_size(size):
    if isinstance(size, str):
        if 'k' in size:
            return float(size.replace('k','')) * 1024
        elif 'M' in size:
            return float(size.replace('M','')) * 1024 * 1024
        elif 'Varies with device' in size:
            return np.nan
    return size

# %%
# Apply Function
df['Size'] = df['Size'].apply(covert_size)

# %%
df['Size']
# Out:
# 0         19922944.0
# 1         14680064.0
# 2          9122611.2
# 3         26214400.0
# 4          2936012.8
# 5          5872025.6
# 6         19922944.0
# 7         30408704.0
# 8         34603008.0
# 9          3250585.6
# 10        29360128.0
# 11        12582912.0
# 12        20971520.0
# 13        22020096.0
# 14        38797312.0
# 15         2831155.2
# 16         5767168.0
# 17        17825792.0
# 18        40894464.0
# 19        32505856.0
# 20        14680064.0
# 21        12582912.0
# 22         4404019.2
# 23         7340032.0
# 24        24117248.0
# 25         6291456.0
# 26        26214400.0
# 27         6396313.6
# 28         4823449.6
# 29         4404019.2
# 30         9646899.2
# 31         5452595.2
# 32        11534336.0
# 33        11534336.0
# 34         4404019.2
# 35         9646899.2
# 36        25165824.0
# 37               NaN
# 38        11534336.0
# 39         9856614.4
# 40        15728640.0
# 41        10485760.0
# 42               NaN
# ...

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews        Size     Installs  Type Price Content Rating  \
# 0      159  19922944.0      10,000+  Free     0       Everyone
# 1      967  14680064.0     500,000+  Free     0       Everyone
# 2    87510   9122611.2   5,000,000+  Free     0       Everyone
# 3   215644  26214400.0  50,000,000+  Free     0           Teen
# 4      967   2936012.8     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# ...

# %%
df.rename(columns={'Size':"Size_in_bytes"}, inplace=True)

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size_in_bytes     Installs  Type Price Content Rating  \
# 0      159     19922944.0      10,000+  Free     0       Everyone
# 1      967     14680064.0     500,000+  Free     0       Everyone
# 2    87510      9122611.2   5,000,000+  Free     0       Everyone
# 3   215644     26214400.0  50,000,000+  Free     0           Teen
# 4      967      2936012.8     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# ...

# %%
df['Size_in_bytes']
# Out:
# 0         19922944.0
# 1         14680064.0
# 2          9122611.2
# 3         26214400.0
# 4          2936012.8
# 5          5872025.6
# 6         19922944.0
# 7         30408704.0
# 8         34603008.0
# 9          3250585.6
# 10        29360128.0
# 11        12582912.0
# 12        20971520.0
# 13        22020096.0
# 14        38797312.0
# 15         2831155.2
# 16         5767168.0
# 17        17825792.0
# 18        40894464.0
# 19        32505856.0
# 20        14680064.0
# 21        12582912.0
# 22         4404019.2
# 23         7340032.0
# 24        24117248.0
# 25         6291456.0
# 26        26214400.0
# 27         6396313.6
# 28         4823449.6
# 29         4404019.2
# 30         9646899.2
# 31         5452595.2
# 32        11534336.0
# 33        11534336.0
# 34         4404019.2
# 35         9646899.2
# 36        25165824.0
# 37               NaN
# 38        11534336.0
# 39         9856614.4
# 40        15728640.0
# 41        10485760.0
# 42               NaN
# ...

# %%
# Create Column Size in Mbs

df['Size_in_mbs'] = df['Size_in_bytes'].apply(lambda x : x/(1024*1024))

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size_in_bytes     Installs  Type Price Content Rating  \
# 0      159     19922944.0      10,000+  Free     0       Everyone
# 1      967     14680064.0     500,000+  Free     0       Everyone
# 2    87510      9122611.2   5,000,000+  Free     0       Everyone
# 3   215644     26214400.0  50,000,000+  Free     0           Teen
# 4      967      2936012.8     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# ...

# %% [markdown]
# ### Let's Take Care Of Installs

# %%
df['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0'], dtype=object)

# %%
df['Installs'].value_counts()
# Out:
# Installs
# 1,000,000+        1579
# 10,000,000+       1252
# 100,000+          1169
# 10,000+           1054
# 1,000+             908
# 5,000,000+         752
# 100+               719
# 500,000+           539
# 50,000+            479
# 5,000+             477
# 100,000,000+       409
# 10+                386
# 500+               330
# 50,000,000+        289
# 50+                205
# 5+                  82
# 500,000,000+        72
# 1+                  67
# 1,000,000,000+      58
# 0+                  14
# 0                    1
# Name: count, dtype: int64

# %%
df['Installs'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Installs Column
# 1. Remove "+" Sign
# 2. Remove ","
# 3. Covert Column into Integer

# %%
# Removw + from Installs
df['Installs'] = df['Installs'].str.replace('+','')

# %%
df['Installs']
# Out:
# 0               10,000
# 1              500,000
# 2            5,000,000
# 3           50,000,000
# 4              100,000
# 5               50,000
# 6               50,000
# 7            1,000,000
# 8            1,000,000
# 9               10,000
# 10           1,000,000
# 11           1,000,000
# 12          10,000,000
# 13             100,000
# 14             100,000
# 15               5,000
# 16             500,000
# 17              10,000
# 18           5,000,000
# 19          10,000,000
# 20             100,000
# 21             100,000
# 22             500,000
# 23             100,000
# 24              50,000
# 25              10,000
# 26             500,000
# 27             100,000
# 28              10,000
# 29             100,000
# 30             100,000
# 31              50,000
# 32             100,000
# 33             100,000
# 34              10,000
# 35             100,000
# 36             500,000
# 37           5,000,000
# 38              10,000
# 39             500,000
# ...

# %%
df['Installs'] = df['Installs'].apply(lambda x : x.replace(',',''))

# %%
df['Installs']
# Out:
# 0             10000
# 1            500000
# 2           5000000
# 3          50000000
# 4            100000
# 5             50000
# 6             50000
# 7           1000000
# 8           1000000
# 9             10000
# 10          1000000
# 11          1000000
# 12         10000000
# 13           100000
# 14           100000
# 15             5000
# 16           500000
# 17            10000
# 18          5000000
# 19         10000000
# 20           100000
# 21           100000
# 22           500000
# 23           100000
# 24            50000
# 25            10000
# 26           500000
# 27           100000
# 28            10000
# 29           100000
# 30           100000
# 31            50000
# 32           100000
# 33           100000
# 34            10000
# 35           100000
# 36           500000
# 37          5000000
# 38            10000
# 39           500000
# 40            10000
# 41           100000
# 42         10000000
# 43           100000
# 44            10000
# ...

# %%
df['Installs'].value_counts()
# Out:
# Installs
# 1000000       1579
# 10000000      1252
# 100000        1169
# 10000         1054
# 1000           908
# 5000000        752
# 100            719
# 500000         539
# 50000          479
# 5000           477
# 100000000      409
# 10             386
# 500            330
# 50000000       289
# 50             205
# 5               82
# 500000000       72
# 1               67
# 1000000000      58
# 0               15
# Name: count, dtype: int64

# %%
# Covert Column into Integer
df['Installs'] = df['Installs'].astype(int)

# %%
df.describe()
# Out:
#             Rating       Reviews  Size_in_bytes      Installs  Size_in_mbs
# count  9367.000000  1.084100e+04   9.146000e+03  1.084100e+04  9146.000000
# mean      4.191513  4.441119e+05   2.255921e+07  1.546291e+07    21.514141
# std       0.515735  2.927629e+06   2.368595e+07  8.502557e+07    22.588679
# min       1.000000  0.000000e+00   8.704000e+03  0.000000e+00     0.008301
# 25%       4.000000  3.800000e+01   5.138022e+06  1.000000e+03     4.900000
# 50%       4.300000  2.094000e+03   1.363149e+07  1.000000e+05    13.000000
# 75%       4.500000  5.476800e+04   3.145728e+07  5.000000e+06    30.000000
# max       5.000000  7.815831e+07   1.048576e+08  1.000000e+09   100.000000

# %%
df['Installs'].min()
# Out:
# np.int64(0)

# %%
df['Installs'].max()
# Out:
# np.int64(1000000000)

# %% [markdown]
# - We have Max & Min values of Installs, So we will create another Column based on Bins

# %%
# make a new column "instal_category" 
bins = [-1,0,10,1000,10000,100000,1000000,10000000,1000000000]
labels = ['no','very low','low','moderate','more tha moderate','high','very high','top notch']
df['Installs_category']  = pd.cut(df['Installs'], bins=bins, labels=labels)

# %%
df['Installs_category'].value_counts()
# Out:
# Installs_category
# low                  2162
# high                 2118
# very high            2004
# more tha moderate    1648
# moderate             1531
# top notch             828
# very low              535
# no                     15
# Name: count, dtype: int64

# %% [markdown]
# ## Price Column

# %%
df['Price'].value_counts()
# Out:
# Price
# 0          10041
# $0.99        148
# $2.99        129
# $1.99         73
# $4.99         72
# $3.99         63
# $1.49         46
# $5.99         30
# $2.49         26
# $9.99         21
# $6.99         13
# $399.99       12
# $14.99        11
# $4.49          9
# $29.99         7
# $3.49          7
# $7.99          7
# $24.99         7
# $5.49          6
# $19.99         6
# $6.49          5
# $8.99          5
# $12.99         5
# $11.99         5
# $10.00         3
# $1.00          3
# $16.99         3
# $2.00          3
# $17.99         2
# $10.99         2
# $9.00          2
# $79.99         2
# $7.49          2
# $3.95          2
# $33.99         2
# $1.70          2
# $13.99         2
# $8.49          2
# $39.99         2
# $1.50          1
# $25.99         1
# $74.99         1
# $15.99         1
# $3.88          1
# $1.76          1
# $3.02          1
# $400.00        1
# $4.84          1
# $2.50          1
# $1.59          1
# $1.61          1
# $4.77          1
# ...

# %%
df['Price'] = df['Price'].apply(lambda x : x.replace('$','') if '$' in x else x)

# %%
df['Price'].value_counts()
# Out:
# Price
# 0         10041
# 0.99        148
# 2.99        129
# 1.99         73
# 4.99         72
# 3.99         63
# 1.49         46
# 5.99         30
# 2.49         26
# 9.99         21
# 6.99         13
# 399.99       12
# 14.99        11
# 4.49          9
# 29.99         7
# 3.49          7
# 7.99          7
# 24.99         7
# 5.49          6
# 19.99         6
# 6.49          5
# 8.99          5
# 12.99         5
# 11.99         5
# 10.00         3
# 1.00          3
# 16.99         3
# 2.00          3
# 17.99         2
# 10.99         2
# 9.00          2
# 79.99         2
# 7.49          2
# 3.95          2
# 33.99         2
# 1.70          2
# 13.99         2
# 8.49          2
# 39.99         2
# 1.50          1
# 25.99         1
# 74.99         1
# 15.99         1
# 3.88          1
# 1.76          1
# 3.02          1
# 400.00        1
# 4.84          1
# 2.50          1
# 1.59          1
# 1.61          1
# 4.77          1
# 5.00          1
# 1.29          1
# 379.99        1
# ...

# %%
# convert into Float
df['Price'] =df['Price'].astype(float)

# %%
# check data type
df['Price'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# - Descriptive Statistics

# %%
df.describe()
# Out:
#             Rating       Reviews  Size_in_bytes      Installs         Price  \
# count  9367.000000  1.084100e+04   9.146000e+03  1.084100e+04  10841.000000
# mean      4.191513  4.441119e+05   2.255921e+07  1.546291e+07      1.027273
# std       0.515735  2.927629e+06   2.368595e+07  8.502557e+07     15.948971
# min       1.000000  0.000000e+00   8.704000e+03  0.000000e+00      0.000000
# 25%       4.000000  3.800000e+01   5.138022e+06  1.000000e+03      0.000000
# 50%       4.300000  2.094000e+03   1.363149e+07  1.000000e+05      0.000000
# 75%       4.500000  5.476800e+04   3.145728e+07  5.000000e+06      0.000000
# max       5.000000  7.815831e+07   1.048576e+08  1.000000e+09    400.000000
#
#        Size_in_mbs
# count  9146.000000
# mean     21.514141
# std      22.588679
# min       0.008301
# 25%       4.900000
# 50%      13.000000
# 75%      30.000000
# max     100.000000

# %%
# using f string calculate Mn, Max and Mean of Price

print(f"Min price of Apps is {df['Price'].min()}")
print(f"Max price of Apps is {df['Price'].max()}")
print(f"Average price of Apps is {df['Price'].mean()}")
# Out:
# Min price of Apps is 0.0
# Max price of Apps is 400.0
# Average price of Apps is 1.0272733142699015

# %% [markdown]
# ---
# ## Observation
# - Now, we have only 6 columns as numeric data type.
# - We can observe their descriptive statistics. and make tons of observations as per our hypotheses.
# - We can see that the Rating column has a minimum value of 1 and a maximum value of 5, which is the range of rating, and the mean is 4.19 which is a good rating. On an average people give this rating.
# - We can see that the Reviews column has a minimum value of 0 and a maximum value of 78,158,306 78+ Millions, which is the range of reviews, and the mean is 444,111.93 which is a good number of reviews. On an average people give this number of reviews to the apps. But it does not make sense to us, as we have different categories of apps.
# - Similarly, we can observe the other columns as well.
# Therefore, the most important thing is to classify as app based on the correlation matrix and then observe the descriptive statistics of the app category and number of installs, reviews, ratings, etc.
# #### But even before that we have to think about the missing values in the dataset.
# ### 2.2. Dealing with the missing values
# Dealing with the missing values is one of the most important part of the data wrangling process, we must deal with the missing values in order to get the correct insights from the data.
# ## Let's Have A Look On Missing Values....
# ---

# %% [markdown]
# ## Missing Values

# %%
# Missing Values

df.isnull().sum().sort_values()
# Out:
# App                     0
# Reviews                 0
# Price                   0
# Installs                0
# Last Updated            0
# Installs_category       0
# Content Rating          0
# Type                    1
# Category                1
# Genres                  1
# Android Ver             2
# Current Ver             8
# Rating               1474
# Size_in_bytes        1695
# Size_in_mbs          1695
# dtype: int64

# %%
# Percentage of Missing Values

df.isnull().sum().sort_values(ascending=False) / df.shape[0] * 100
# Out:
# Size_in_bytes        15.635089
# Size_in_mbs          15.635089
# Rating               13.596532
# Current Ver           0.073794
# Android Ver           0.018448
# Type                  0.009224
# Category              0.009224
# Genres                0.009224
# Installs              0.000000
# App                   0.000000
# Reviews               0.000000
# Last Updated          0.000000
# Content Rating        0.000000
# Price                 0.000000
# Installs_category     0.000000
# dtype: float64

# %%
# Find total Number of Missing Values
df.isnull().sum().sum()
# Out:
# np.int64(4877)

# %%
# Plot Missing Values
plt.figure(figsize=(20,7))
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# - Let's plot the missing values other than 'Rating', 'Size_in_bytes' and 'Size_in_Mb' column
# - We have missing percentage columns other than rating having less than one percent of missing values, we will plot them as follows:

# %%
# bar ploat according to missng values
plt.figure(figsize=(20,7))
missing_percentage = df.isnull().sum() / len(df) * 100
missing_percentage.plot(kind = 'bar')

plt.xlabel('Columns')
plt.ylabel('Percentage')
plt.title('Percentage of Missing Values')
# Out:
# Text(0.5, 1.0, 'Percentage of Missing Values')

# %%
missing_percentage[missing_percentage < 1].plot(kind = 'bar')
# Out:
# <Axes: >

# %%
# Percentage of Missing Values

df.isnull().sum().sort_values(ascending=False) / df.shape[0] * 100
# Out:
# Size_in_bytes        15.635089
# Size_in_mbs          15.635089
# Rating               13.596532
# Current Ver           0.073794
# Android Ver           0.018448
# Type                  0.009224
# Category              0.009224
# Genres                0.009224
# Installs              0.000000
# App                   0.000000
# Reviews               0.000000
# Last Updated          0.000000
# Content Rating        0.000000
# Price                 0.000000
# Installs_category     0.000000
# dtype: float64

# %% [markdown]
# ---
# ## Observation
# - We have 1695 missing values in the 'Size_in_bytes' and 'Size_in_Mb' columns, which is 15.6% of the total values in the column.
# - We have 1474 missing values in the 'Rating' column, which is 13.6% of the total values in the column.
# - We have 8 missing value in the 'Current Ver' column, which is 0.07% of the total values in the column.
# - We have 2 missing values in the 'Android Ver' column, which is 0.01% of the total values in the column.
# - We have only 1 missing value in Category, Type and Genres columns, which is 0.009% of the total values in the column.
# ### 2.3. Dealing with the missing values
# - We can not impute the Rating column as is is directly linked with the installation column. To test this Hypothesis we need to plot the Rating column with the Installs and Size columns and statistically test it using pearson correlation test.
# ---

# %% [markdown]
# ### Let's Run Co-reltation

# %%
# These are numeric Columns

df.describe()
# Out:
#             Rating       Reviews  Size_in_bytes      Installs         Price  \
# count  9367.000000  1.084100e+04   9.146000e+03  1.084100e+04  10841.000000
# mean      4.191513  4.441119e+05   2.255921e+07  1.546291e+07      1.027273
# std       0.515735  2.927629e+06   2.368595e+07  8.502557e+07     15.948971
# min       1.000000  0.000000e+00   8.704000e+03  0.000000e+00      0.000000
# 25%       4.000000  3.800000e+01   5.138022e+06  1.000000e+03      0.000000
# 50%       4.300000  2.094000e+03   1.363149e+07  1.000000e+05      0.000000
# 75%       4.500000  5.476800e+04   3.145728e+07  5.000000e+06      0.000000
# max       5.000000  7.815831e+07   1.048576e+08  1.000000e+09    400.000000
#
#        Size_in_mbs
# count  9146.000000
# mean     21.514141
# std      22.588679
# min       0.008301
# 25%       4.900000
# 50%      13.000000
# 75%      30.000000
# max     100.000000

# %%
# make a corelation matrix of numeric columns
plt.figure(figsize=(16,8))
numeric_columns = ['Rating','Reviews','Size_in_bytes','Installs','Price','Size_in_mbs']
sns.heatmap(df[numeric_columns].corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ---
# ## Observation
# - Lighter color shows the high correlation and darker color shows the low correlation
# - We can see that the Reviews column has a high correlation with the Installs column, which is 0.64 according to corr(). Which is quite good.
# - This shows that the more the reviews the more the installs are for one app. If in any case we need to impute reviews we have to think of number of install.
# - If we have an ap with 2 installs and we imputer the reviews with 1000 or via average reviews then it will be wrong.
# - Installs is slightly correlated with Size_in_Mb or Size_in_bytes , which is 0.16, this also shows us the importance of size and Installs. But we can not depend on it as the Peason correlation is very low.
#
# ---
#
# - Before going ahead, let's remove the rows with missing values in the Current Ver, Android Ver, Category, Type and Genres columns, as they are very less in number and will not affect our analysis.

# %%
# Lenght before Removing Null Values

print(f"Lenght of Dataframe before Removing Null Values : {len(df)}")
# Out:
# Lenght of Dataframe before Removing Null Values : 10841

# %%
# drop null values in 'Current Ver','Android Ver','Category','Type','Genres' Columns
df.dropna(subset=['Current Ver','Android Ver','Category','Type','Genres'], inplace=True)

# %%
# Lenght After Removing Null Values

print(f"Lenght of Dataframe After Removing Null Values : {len(df)}")
# Out:
# Lenght of Dataframe After Removing Null Values : 10829

# %% [markdown]
# - We Removed 12 Rows

# %%
# Let's Check Null Values
df.isnull().sum().sort_values(ascending=False)
# Out:
# Size_in_bytes        1694
# Size_in_mbs          1694
# Rating               1469
# Category                0
# Reviews                 0
# Installs                0
# App                     0
# Type                    0
# Price                   0
# Genres                  0
# Content Rating          0
# Last Updated            0
# Current Ver             0
# Android Ver             0
# Installs_category       0
# dtype: int64

# %% [markdown]
# ---
# ## Observation
# - Only Rating and Size_in_bytes or Size_in_Mb columns are left with missing values.
# - We know that we have to be carefull while deadling with Rating column, as it is directly linked with the Installs column.
# - In Size columns we already know about Varies with device values, which we have converted into null values, we do not need to impute at the moment, as every app has different size and nobody can predict that as nearly as possible.
# ---

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size_in_bytes', 'Installs',
#        'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated',
#        'Current Ver', 'Android Ver', 'Size_in_mbs', 'Installs_category'],
#       dtype='object')

# %%
# Find Trend of Rating with Installs_category
df.groupby('Installs_category')['Rating'].describe()
# Out:
#                     count      mean       std  min  25%  50%  75%  max
# Installs_category
# no                    0.0       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# very low             81.0  4.637037  0.845199  1.0  4.8  5.0  5.0  5.0
# low                1278.0  4.170970  0.825605  1.0  3.8  4.4  4.8  5.0
# moderate           1440.0  4.035417  0.604428  1.4  3.8  4.2  4.5  5.0
# more tha moderate  1616.0  4.093255  0.505619  1.6  3.9  4.2  4.5  4.9
# high               2113.0  4.207525  0.376594  1.8  4.0  4.3  4.5  4.9
# very high          2004.0  4.287076  0.294902  2.0  4.1  4.3  4.5  4.9
# top notch           828.0  4.374396  0.193726  3.1  4.3  4.4  4.5  4.8

# %%
df['Rating'].isnull().sum()
# Out:
# np.int64(1469)

# %%
# in which Install_category the Rating has NaN values
df['Installs_category'].loc[df['Rating'].isnull()].value_counts()
# Out:
# Installs_category
# low                  880
# very low             453
# moderate              88
# more tha moderate     31
# no                    14
# high                   3
# very high              0
# top notch              0
# Name: count, dtype: int64

# %%
# find mean of rating for each install_category
df.groupby('Installs_category')['Rating'].mean()
# Out:
# Installs_category
# no                        NaN
# very low             4.637037
# low                  4.170970
# moderate             4.035417
# more tha moderate    4.093255
# high                 4.207525
# very high            4.287076
# top notch            4.374396
# Name: Rating, dtype: float64

# %%
# impute the missing values of Rating with respective to the means of its install_category

df['Rating'].fillna(df.groupby('Installs_category')['Rating'].transform('mean'), inplace=True)

# %%
# check null values
df['Rating'].isnull().sum()
# Out:
# np.int64(14)

# %% [markdown]
# #### Means there are 14 rows where Install Count is "0", So there is nan

# %%
# Check Unique Values
df['Rating'].unique()
# Out:
# array([4.1       , 3.9       , 4.7       , 4.5       , 4.3       ,
#        4.4       , 3.8       , 4.2       , 4.6       , 4.        ,
#        4.09325495, 4.8       , 4.9       , 3.6       , 3.7       ,
#        3.2       , 4.03541667, 3.3       , 3.4       , 3.5       ,
#        3.1       , 5.        , 2.6       , 4.17097027, 3.        ,
#        1.9       , 2.5       , 2.8       , 2.7       , 1.        ,
#        4.63703704, 2.9       , 4.20752485, 2.3       , 2.2       ,
#        1.7       , 2.        , 1.8       , 2.4       ,        nan,
#        1.6       , 2.1       , 1.4       , 1.5       , 1.2       ])

# %%
df['Rating'].value_counts().sort_values(ascending=True)
# Out:
# Rating
# 1.200000       1
# 1.400000       3
# 1.500000       3
# 4.207525       3
# 1.600000       4
# 1.700000       8
# 2.100000       8
# 1.800000       8
# 2.000000      12
# 1.900000      13
# 2.200000      14
# 1.000000      16
# 2.400000      19
# 2.300000      20
# 2.500000      21
# 2.600000      25
# 2.700000      25
# 4.093255      31
# 2.800000      42
# 2.900000      45
# 3.200000      63
# 3.100000      69
# 3.000000      83
# 4.900000      87
# 4.035417      88
# 3.300000     102
# 3.400000     128
# 3.500000     163
# 3.600000     174
# 4.800000     234
# 3.700000     239
# 5.000000     274
# 3.800000     303
# 3.900000     386
# 4.637037     453
# 4.700000     499
# 4.000000     567
# 4.100000     707
# 4.600000     823
# 4.170970     880
# 4.200000     951
# 4.500000    1037
# 4.300000    1076
# 4.400000    1108
# Name: count, dtype: int64

# %%
# check null values
df['Rating'].isnull().sum()
# Out:
# np.int64(14)

# %%
# in which Install_category the Rating has NaN values
df['Installs_category'].loc[df['Rating'].isnull()].value_counts()
# Out:
# Installs_category
# no                   14
# very low              0
# low                   0
# moderate              0
# more tha moderate     0
# high                  0
# very high             0
# top notch             0
# Name: count, dtype: int64

# %%
df['Installs_category'].value_counts()
# Out:
# Installs_category
# low                  2158
# high                 2116
# very high            2004
# more tha moderate    1647
# moderate             1528
# top notch             828
# very low              534
# no                     14
# Name: count, dtype: int64

# %%
# plot the box plot rating according to install category
plt.figure(figsize=(20,8))
sns.boxplot(x='Installs_category', y='Rating', hue='Installs_category', data=df)
# Out:
# <Axes: xlabel='Installs_category', ylabel='Rating'>

# %% [markdown]
# - Let's Check Install_category Reviews Has Null Values

# %%
df['Installs_category'].loc[df['Reviews'].isnull()].value_counts()             # There is No Null Value
# Out:
# Installs_category
# no                   0
# very low             0
# low                  0
# moderate             0
# more tha moderate    0
# high                 0
# very high            0
# top notch            0
# Name: count, dtype: int64

# %% [markdown]
# - Let's Plot Same Box Plot for Reviews

# %%
plt.figure(figsize=(20,8))
sns.boxplot(x='Installs_category', y='Reviews', hue='Installs_category', data=df)
# Out:
# <Axes: xlabel='Installs_category', ylabel='Reviews'>

# %% [markdown]
# - Data Looks Imbalance, Let's Normaize It

# %%
plt.figure(figsize=(20,8))
sns.boxplot(x='Installs_category', y=np.log(df['Reviews']), hue='Installs_category', data=df)
# Out:
# <Axes: xlabel='Installs_category', ylabel='Reviews'>

# %%
# Draw A Scaterplot between Rating Reviews and Installs_category
plt.figure(figsize=(20,8))
sns.scatterplot(x='Rating',y='Reviews',hue='Installs_category',data=df)
# Out:
# <Axes: xlabel='Rating', ylabel='Reviews'>

# %%
# plot reviews and installs in scatter plot with trend lins
plt.figure(figsize=(20,8))
sns.lmplot(x='Reviews',y='Installs', data=df)

# %% [markdown]
# - Have Shows More Reviews Get More Install In Apps

# %% [markdown]
# ---
# ## Observation
# -We can see that if the app has less installations, it has less Rating and review.
# - But wait, we have to check for the duplicates as well, as they can affect our analysis.
# ### 2.3. Duplicates
# - Removing duplicates is one of the most important part of the data wrangling process, we must remove the duplicates in order to get the correct insights from the data.
# - If you do not remove duplicates from a dataset, it can lead to incorrect insights and analysis.
# - Duplicates can skew statistical measures such as mean, median, and standard deviation, and can also lead to over-representation of certain data points.
# - It is important to remove duplicates to ensure the accuracy and reliability of your data analysis.
# ---

# %%
# find duplicate values if any
df.duplicated().sum()
# Out:
# np.int64(483)

# %% [markdown]
# This shows us total duplicates, but we can also check based on the app name, as we know that every app has a unique name.

# %%
df['App'].duplicated().sum()
# Out:
# np.int64(1181)

# %% [markdown]
# - Oops! we have 1181 dupicate app names
# - Can we find a column which can help us to remove the duplicates?
# - let's check for number of duplicates in each column using a for loop and printing the output

# %%
# Let's Check No of Duplicates in Each Column
for col in df.columns:
    print(f"No of Duplicate Values in {col} Are : {df[col].duplicated().sum()}")
# Out:
# No of Duplicate Values in App Are : 1181
# No of Duplicate Values in Category Are : 10796
# No of Duplicate Values in Rating Are : 10784
# No of Duplicate Values in Reviews Are : 4830
# No of Duplicate Values in Size_in_bytes Are : 10373
# No of Duplicate Values in Installs Are : 10809
# No of Duplicate Values in Type Are : 10827
# No of Duplicate Values in Price Are : 10737
# No of Duplicate Values in Content Rating Are : 10823
# No of Duplicate Values in Genres Are : 10710
# No of Duplicate Values in Last Updated Are : 9453
# No of Duplicate Values in Current Ver Are : 7998
# No of Duplicate Values in Android Ver Are : 10796
# No of Duplicate Values in Size_in_mbs Are : 10373
# No of Duplicate Values in Installs_category Are : 10821

# %% [markdown]
# - Because Each row has More dulicate Values
# - We will check collectively Duplicate Values

# %%
print(f"No of Duplicate values in DF : {df.duplicated().sum()}")
# Out:
# No of Duplicate values in DF : 483

# %% [markdown]
# - Find and Check Duplicates are Real or Not

# %%
# FIND Exact Duplicate Values
df[df['App'].duplicated(keep=False)].sort_values('App')
# Out:
#                                                      App             Category  \
# 1393                               10 Best Foods for You   HEALTH_AND_FITNESS
# 1407                               10 Best Foods for You   HEALTH_AND_FITNESS
# 2543                          1800 Contacts - Lens Store              MEDICAL
# 2322                          1800 Contacts - Lens Store              MEDICAL
# 2385                          2017 EMRA Antibiotic Guide              MEDICAL
# 2256                          2017 EMRA Antibiotic Guide              MEDICAL
# 1337                        21-Day Meditation Experience   HEALTH_AND_FITNESS
# 1434                        21-Day Meditation Experience   HEALTH_AND_FITNESS
# 3083                             365Scores - Live Scores               SPORTS
# 5415                             365Scores - Live Scores               SPORTS
# 7035                              420 BZ Budeze Delivery              MEDICAL
# ...

# %% [markdown]
# ### See That are Exact Same Values
# #### Removing Duplicates

# %%
# Remove Duplicates
df.drop_duplicates(inplace=True)

# %%
print(f"No of DataFrame after removing Duplicate Values : {df.shape[0]}")
# Out:
# No of DataFrame after removing Duplicate Values : 10346

# %% [markdown]
# - Now we have removed 483 duplicates from the dataset. and have 10346 rows left.

# %% [markdown]
# ## 3. Insights from Data
# ### 3.1. Which category has the highest number of apps?

# %%
# Which Category has Highest Number of APPS
df['Category'].value_counts().head(10)
# Out:
# Category
# FAMILY             1939
# GAME               1121
# TOOLS               841
# BUSINESS            427
# MEDICAL             408
# PRODUCTIVITY        407
# PERSONALIZATION     386
# LIFESTYLE           373
# COMMUNICATION       366
# FINANCE             360
# Name: count, dtype: int64

# %% [markdown]
# ### 3.2. Which category has the highest number of installs?

# %%
df.groupby('Category')['Installs'].sum().sort_values(ascending=False).head(10)
# Out:
# Category
# GAME                  31544024415
# COMMUNICATION         24152276251
# SOCIAL                12513867902
# PRODUCTIVITY          12463091369
# TOOLS                 11452271905
# FAMILY                10041632405
# PHOTOGRAPHY            9721247655
# TRAVEL_AND_LOCAL       6361887146
# VIDEO_PLAYERS          6222002720
# NEWS_AND_MAGAZINES     5393217760
# Name: Installs, dtype: int64

# %% [markdown]
# ### 3.3. Which category has the highest number of reviews?

# %%
df.groupby('Category')['Reviews'].sum().sort_values(ascending=False).head(10)
# Out:
# Category
# GAME               1415536650
# COMMUNICATION       601273552
# SOCIAL              533576829
# FAMILY              396771746
# TOOLS               273181033
# PHOTOGRAPHY         204297410
# VIDEO_PLAYERS       110380188
# PRODUCTIVITY        102554498
# SHOPPING             94931162
# PERSONALIZATION      75192744
# Name: Reviews, dtype: int64

# %% [markdown]
# ### 3.4. Which category has the highest rating?

# %%
df.groupby('Category')['Rating'].mean().sort_values(ascending=False).head(10)
# Out:
# Category
# EVENTS                 4.394346
# EDUCATION              4.373794
# ART_AND_DESIGN         4.367122
# BOOKS_AND_REFERENCE    4.358435
# PERSONALIZATION        4.333325
# GAME                   4.281926
# HEALTH_AND_FITNESS     4.273890
# SOCIAL                 4.260441
# PARENTING              4.259759
# SHOPPING               4.253376
# Name: Rating, dtype: float64

# %%
# Plot The Rating Distribution
plt.figure(figsize=(16,5))
sns.kdeplot(df['Rating'], color='blue', shade=True)
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %% [markdown]
# ### plot number of installs for free vs paid apps make a bar plot

# %%
plt.figure(figsize=(16,5))
sns.barplot(x='Type', y='Installs', data=df)
# Out:
# <Axes: xlabel='Type', ylabel='Installs'>

# %%
# make a bar plot of Size_in_Mb vs Installs_category

plt.figure(figsize=(16,5))
sns.barplot(x='Installs_category', y='Size_in_mbs', data=df)
# Out:
# <Axes: xlabel='Installs_category', ylabel='Size_in_mbs'>
